# %% [markdown]
# # Twitter stats
# ## Farmers Protest Tweets
#
# ### Libraries

# %%
import re
import pandas as pd

# %% [markdown]
# ### Functions

# %%
def most_retweet(data):
    return data.sort_values(by=["retweetCount"], ascending=False).head(10)

# %%
def top_users(data):
    data["username"] = data["user"].apply(lambda x: x.get("username"))
    return data.groupby("username", sort=True).size().to_frame("size").sort_values(by="size", ascending=False).head(10)

# %%
def most_active_days(data):
    data.rename(columns = {"date": "datetime"})
    data["date"] = pd.to_datetime(df['datetime']).dt.date
    return data.groupby("date").size().to_frame("size").sort_values(by="size", ascending=False).head(10)

# %% [markdown]
# ### Main code

# %%
df = pd.read_json("farmers-protest-tweets-2021-03-5.json", lines=True)

# %%
df
# Out:
#                                                       url  \
# 0       https://twitter.com/ShashiRajbhar6/status/1376...
# 1       https://twitter.com/kaursuk06272818/status/137...
# 2       https://twitter.com/kaursuk06272818/status/137...
# 3       https://twitter.com/SukhdevSingh_/status/13767...
# 4       https://twitter.com/Davidmu66668113/status/137...
# ...                                                   ...
# 419502  https://twitter.com/TeamSOOUDA/status/13560306...
# 419503  https://twitter.com/VibhaBurman/status/1356030...
# 419504  https://twitter.com/NavJammu/status/1356029858...
# 419505  https://twitter.com/Atwal72/status/13560296726...
# 419506  https://twitter.com/Manjind22050118/status/135...
#
#                             date  \
# 0      2021-03-30 03:33:46+00:00
# 1      2021-03-30 03:33:23+00:00
# 2      2021-03-30 03:31:00+00:00
# 3      2021-03-30 03:30:45+00:00
# 4      2021-03-30 03:30:30+00:00
# ...                          ...
# ...

# %%
print(most_retweet(df))
# Out:
#                                                       url  \
# 408128  https://twitter.com/rihanna/status/13566258896...
# 395142  https://twitter.com/GretaThunberg/status/13566...
# 266196  https://twitter.com/GretaThunberg/status/13572...
# 366579  https://twitter.com/miakhalifa/status/13568483...
# 372793  https://twitter.com/miakhalifa/status/13568277...
# 314192  https://twitter.com/TeamJuJu/status/1357048037...
# 215034  https://twitter.com/BobBlackman/status/1357755...
# 398011  https://twitter.com/vanessa_vash/status/135668...
# 325261  https://twitter.com/kylekuzma/status/135700972...
# 163689  https://twitter.com/AmandaCerny/status/1359013...
#
#                             date  \
# 408128 2021-02-02 15:29:51+00:00
# 395142 2021-02-02 20:04:01+00:00
# 266196 2021-02-04 10:59:01+00:00
# 366579 2021-02-03 06:14:01+00:00
# 372793 2021-02-03 04:51:48+00:00
# 314192 2021-02-03 19:27:19+00:00
# 215034 2021-02-05 18:19:19+00:00
# 398011 2021-02-02 19:09:23+00:00
# ...

# %%
print(top_users(df))
# Out:
#                  size
# username
# harjot_tweeting  7134
# tasveersandhu    2091
# shells_n_petals  1991
# jot__b           1841
# rebelpacifist    1806
# rumsomal         1722
# Iamjazzie96      1502
# Jass_k_G         1460
# DigitalKisanBot  1453
# z_khalique007    1446

# %%
print(most_active_days(df))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/twitter-stats-Wl82EdEs-py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/Library/Caches/pypoetry/virtualenvs/twitter-stats-Wl82EdEs-py3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/Caches/pypoetry/virtualenvs/twitter-stats-Wl82EdEs-py3.10/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
